# %%
# from sqlalchemy import create_engine, Column, Integer, String
# from sqlalchemy.orm import sessionmaker, declarative_base

# # 设置SQLite引擎和会话
# sqlite_engine = create_engine("sqlite:///./test.db", connect_args={"check_same_thread": False})
# Base = declarative_base()
# SessionSQLite = sessionmaker(bind=sqlite_engine)
# session = SessionSQLite()

# # 定义Category类
# class Category(Base):
#     __tablename__ = 'category'
#     category_id = Column(Integer, primary_key=True)
#     parent_id = Column(Integer, nullable=False)

# # 读取数据并构建邻接矩阵字典
# def build_adjacency_list():
#     categories = session.query(Category).all()
#     adjacency_list = {}
#     root_nodes = []

#     for category in categories:
#         if category.parent_id == 0:
#             root_nodes.append(category.category_id)
        
#         if category.parent_id not in adjacency_list:
#             adjacency_list[category.parent_id] = []
#         adjacency_list[category.parent_id].append(category.category_id)
    
#     return adjacency_list, root_nodes

# adjacency_list, root_nodes = build_adjacency_list()


# print("Adjacency List:")
# for parent_id, children in adjacency_list.items():
#     print(f"Parent ID: {parent_id}, Children: {children}")

# print("\nRoot Nodes:")
# print(root_nodes)

# %%
from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.orm import sessionmaker, declarative_base

# 设置SQLite引擎和会话
sqlite_engine = create_engine("sqlite:///./test.db", connect_args={"check_same_thread": False})
Base = declarative_base()
SessionSQLite = sessionmaker(bind=sqlite_engine)
session = SessionSQLite()

# 定义Category类
class Category(Base):
    __tablename__ = 'category'
    category_id = Column(Integer, primary_key=True)
    parent_id = Column(Integer, nullable=False)
    name = Column(String(255), nullable=False)

# %%
# 读取数据并构建邻接矩阵字典
categories = session.query(Category).all()
adjacency_list = {}
name_dict = {}
root_nodes = []

for category in categories:
    name_dict[category.category_id] = category.name
    if category.parent_id == 0:
        root_nodes.append(category.category_id)

    if category.parent_id not in adjacency_list:
        adjacency_list[category.parent_id] = []
    adjacency_list[category.parent_id].append(category.category_id)

print("Adjacency List:")
for parent_id, children in adjacency_list.items():
    print(f"Parent ID: {parent_id}, Children: {children}")

print("\nRoot Nodes:")
print(root_nodes)

# 构建树结构
def build_tree(node_id, adjacency_list, name_dict):
    node = {"id": node_id, "name": name_dict[node_id]}
    if node_id in adjacency_list:
        children = [build_tree(child_id, adjacency_list, name_dict) for child_id in adjacency_list[node_id]]
        if children:  # 仅当存在子节点时才添加children字段
            node["children"] = children
    return node


tree_structure = [build_tree(root_id, adjacency_list, name_dict) for root_id in root_nodes]

# # 移除空的 children
# def remove_empty_children(node):
#     if "children" in node:
#         if not node["children"]:
#             node.pop("children")
#         else:
#             for child in node["children"]:
#                 remove_empty_children(child)

# for tree in tree_structure:
#     remove_empty_children(tree)

print("\nTree Structure:")
import json
print(json.dumps(tree_structure, indent=4, ensure_ascii=False))

# 关闭会话
session.close()
# Out:
# Adjacency List:
# Parent ID: 0, Children: [107, 237, 238, 242, 306, 395, 399, 408, 415, 420, 425, 429, 434, 441, 445, 449, 454, 455]
# Parent ID: 306, Children: [232, 234, 235, 307, 308, 317]
# Parent ID: 242, Children: [243, 245, 246, 310]
# Parent ID: 243, Children: [244, 297]
# Parent ID: 310, Children: [248, 311]
# Parent ID: 237, Children: [249, 309, 435, 436, 437, 438, 439, 440]
# Parent ID: 248, Children: [250, 251, 252, 253, 254]
# Parent ID: 238, Children: [255, 256, 259, 295, 324, 333, 352, 355, 360, 457]
# Parent ID: 255, Children: [257, 322, 328, 456]
# Parent ID: 256, Children: [260]
# Parent ID: 257, Children: [261, 263, 265, 267, 269, 270, 271, 320, 321, 323, 338, 339]
# Parent ID: 259, Children: [274, 275, 276, 367]
# Parent ID: 260, Children: [278, 279, 280]
# Parent ID: 245, Children: [286, 298]
# Parent ID: 286, Children: [287, 288, 289, 290, 291]
# Parent ID: 244, Children: [293, 294]
# Parent ID: 295, Children: [296]
# Parent ID: 298, Children: [299, 301, 303, 304, 305]
# Parent ID: 297, Children: [300, 302]
# Parent ID: 311, Children: [312, 313, 314, 315, 316]
# Parent ID: 246, Children: [318, 319]
# Parent ID: 324, Children: [325, 389]
# Parent ID: 325, Children: [326, 327, 340, 341, 342]
# Parent ID: 307, Children: [329, 332]
# Parent ID: 329, Children: [330, 331]
# Parent ID: 333, Children: [334, 335, 336]
# Parent ID: 360, Children: [343]
# Parent ID: 343, Children: [344, 345, 346, 347, 348, 349, 350, 351]
# Parent ID: 352, Children: [353, 354]
# Parent ID: 355, Children: [356, 394]
# Parent ID: 308, Children: [366]
# Parent ID: 389, Children: [390, 391, 392, 393, 396, 397, 398]
# Parent ID: 399, Children: [400, 401, 402, 403, 404, 405, 406, 407]
# Parent ID: 408, Children: [409, 410, 411, 412, 413, 414]
# Parent ID: 415, Children: [416, 417, 418, 419]
# Parent ID: 420, Children: [421, 422, 423, 424]
# Parent ID: 425, Children: [426, 427, 428]
# Parent ID: 429, Children: [430, 431, 432, 433]
# Parent ID: 441, Children: [442, 443, 444]
# Parent ID: 445, Children: [446, 447, 448]
# Parent ID: 449, Children: [450, 451, 452, 453]
# Parent ID: 457, Children: [458, 459]
#
# Root Nodes:
# [107, 237, 238, 242, 306, 395, 399, 408, 415, 420, 425, 429, 434, 441, 445, 449, 454, 455]
#
# Tree Structure:
# [
#     {
#         "id": 107,
#         "name": "Sensor"
#     },
#     {
#         "id": 237,
#         "name": "Robotics",
#         "children": [
#             {
#                 "id": 249,
#                 "name": "Accessories"
#             },
#             {
#                 "id": 309,
#                 "name": "Component"
#             },
#             {
#                 "id": 435,
#                 "name": "Mobile Robots"
#             },
#             {
#                 "id": 436,
#                 "name": "Dog-like Robots"
#             },
#             {
#                 "id": 437,
#                 "name": "Drivers / Sensors / Lidar"
#             },
#             {
#                 "id": 438,
#                 "name": "Motors / Servos"
#             },
#             {
#                 "id": 439,
#                 "name": "Robot Arm / Control"
#             },
#             {
#                 "id": 440,
#                 "name": "Robotic Components"
#             }
#         ]
#     },
#     {
#         "id": 238,
#         "name": "Prototyping",
#         "children": [
#             {
#                 "id": 255,
#                 "name": "Connector Plug",
#                 "children": [
#                     {
#                         "id": 257,
#                         "name": "JST Connector",
#                         "children": [
#                             {
#                                 "id": 261,
#                                 "name": "JST PH"
#                             },
#                             {
#                                 "id": 263,
#                                 "name": "JST XH"
#                             },
#                             {
#                                 "id": 265,
#                                 "name": "JST PA"
#                             },
#                             {
#                                 "id": 267,
#                                 "name": "JST XA"
#                             },
#                             {
#                                 "id": 269,
#                                 "name": "JST SM"
#                             },
#                             {
#                                 "id": 270,
#                                 "name": "JST EL"
#                             },
#                             {
#                                 "id": 271,
#                                 "name": "JST SYP"
#                             },
#                             {
#                                 "id": 320,
#                                 "name": "JST ZH"
#                             },
#                             {
#                                 "id": 321,
#                                 "name": "JST VH"
#                             },
#                             {
#                                 "id": 323,
#                                 "name": "JST CH"
#                             },
#                             {
#                                 "id": 338,
#                                 "name": "JST GH"
#                             },
#                             {
#                                 "id": 339,
#                                 "name": "JST SH"
#                             }
#                         ]
#                     },
#                     {
#                         "id": 322,
#                         "name": "DuPont"
#                     },
#                     {
#                         "id": 328,
#                         "name": "Molex"
#                     },
#                     {
#                         "id": 456,
#                         "name": "Automotive Connector"
#                     }
#                 ]
#             },
#             {
#                 "id": 256,
#                 "name": "Speaker",
#                 "children": [
#                     {
#                         "id": 260,
#                         "name": "Speaker CQR3070",
#                         "children": [
#                             {
#                                 "id": 278,
#                                 "name": "8Ω5W"
#                             },
#                             {
#                                 "id": 279,
#                                 "name": "8Ω3W"
#                             },
#                             {
#                                 "id": 280,
#                                 "name": "4Ω3W"
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "id": 259,
#                 "name": "Serial Port Converter",
#                 "children": [
#                     {
#                         "id": 274,
#                         "name": "USB to RS422 or RS485"
#                     },
#                     {
#                         "id": 275,
#                         "name": "RS232 to RS422/RS485"
#                     },
#                     {
#                         "id": 276,
#                         "name": "RS232 to RS485"
#                     },
#                     {
#                         "id": 367,
#                         "name": "USB to RS232"
#                     }
#                 ]
#             },
#             {
#                 "id": 295,
#                 "name": "Connect Cable",
#                 "children": [
#                     {
#                         "id": 296,
#                         "name": "XT60 Cable"
#                     }
#                 ]
#             },
#             {
#                 "id": 324,
#                 "name": "Screws and Nuts",
#                 "children": [
#                     {
#                         "id": 325,
#                         "name": "PC Clear Acrylic",
#                         "children": [
#                             {
#                                 "id": 326,
#                                 "name": "M3"
#                             },
#                             {
#                                 "id": 327,
#                                 "name": "M2.5"
#                             },
#                             {
#                                 "id": 340,
#                                 "name": "M4"
#                             },
#                             {
#                                 "id": 341,
#                                 "name": "M5"
#                             },
#                             {
#                                 "id": 342,
#                                 "name": "M6"
#                             }
#                         ]
#                     },
#                     {
#                         "id": 389,
#                         "name": "Nylon Black",
#                         "children": [
#                             {
#                                 "id": 390,
#                                 "name": "M2"
#                             },
#                             {
#                                 "id": 391,
#                                 "name": "M2.5"
#                             },
#                             {
#                                 "id": 392,
#                                 "name": "M3"
#                             },
#                             {
#                                 "id": 393,
#                                 "name": "M4"
#                             },
#                             {
#                                 "id": 396,
#                                 "name": "M5"
#                             },
#                             {
#                                 "id": 397,
#                                 "name": "M6"
#                             },
#                             {
#                                 "id": 398,
#                                 "name": "M8"
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "id": 333,
#                 "name": "Jumper Cap",
#                 "children": [
#                     {
#                         "id": 334,
#                         "name": "5.08mm"
#                     },
#                     {
#                         "id": 335,
#                         "name": "2.54mm"
#                     },
#                     {
#                         "id": 336,
#                         "name": "2.0mm"
#                     }
#                 ]
#             },
#             {
#                 "id": 352,
#                 "name": "PCB Soldering Terminal",
#                 "children": [
#                     {
#                         "id": 353,
#                         "name": "M3"
#                     },
#                     {
#                         "id": 354,
#                         "name": "M4"
#                     }
#                 ]
#             },
#             {
#                 "id": 355,
#                 "name": "IDC Box Header Connector",
#                 "children": [
#                     {
#                         "id": 356,
#                         "name": "2.54mm Pitch"
#                     },
#                     {
#                         "id": 394,
#                         "name": "2.0mm Pitch"
#                     }
#                 ]
#             },
#             {
#                 "id": 360,
#                 "name": "DIP Switch SMT",
#                 "children": [
#                     {
#                         "id": 343,
#                         "name": "1.27 mm Pitch",
#                         "children": [
#                             {
#                                 "id": 344,
#                                 "name": "1 Position"
#                             },
#                             {
#                                 "id": 345,
#                                 "name": "2 Position"
#                             },
#                             {
#                                 "id": 346,
#                                 "name": "3 Position"
#                             },
#                             {
#                                 "id": 347,
#                                 "name": "4 Position"
#                             },
#                             {
#                                 "id": 348,
#                                 "name": "5 Position"
#                             },
#                             {
#                                 "id": 349,
#                                 "name": "6 Position"
#                             },
#                             {
#                                 "id": 350,
#                                 "name": "8 Position"
#                             },
#                             {
#                                 "id": 351,
#                                 "name": "10 Position"
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "id": 457,
#                 "name": "DC Power Plug",
#                 "children": [
#                     {
#                         "id": 458,
#                         "name": "Female Plug"
#                     },
#                     {
#                         "id": 459,
#                         "name": "Male Plug"
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "id": 242,
#         "name": "DC Gearmotors ",
#         "children": [
#             {
#                 "id": 243,
#                 "name": "Diameter 37mm",
#                 "children": [
#                     {
#                         "id": 244,
#                         "name": "With Encoder",
#                         "children": [
#                             {
#                                 "id": 293,
#                                 "name": "12V With Encoder"
#                             },
#                             {
#                                 "id": 294,
#                                 "name": "24V With Encoder"
#                             }
#                         ]
#                     },
#                     {
#                         "id": 297,
#                         "name": "Without Encoder",
#                         "children": [
#                             {
#                                 "id": 300,
#                                 "name": "12V Without Encoder"
#                             },
#                             {
#                                 "id": 302,
#                                 "name": "24V Without Encoder"
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "id": 245,
#                 "name": "Diameter 25mm",
#                 "children": [
#                     {
#                         "id": 286,
#                         "name": "With Encoder",
#                         "children": [
#                             {
#                                 "id": 287,
#                                 "name": "6V With-Encoder HP"
#                             },
#                             {
#                                 "id": 288,
#                                 "name": "6V With-Encoder LP"
#                             },
#                             {
#                                 "id": 289,
#                                 "name": "12V With-Encoder HP"
#                             },
#                             {
#                                 "id": 290,
#                                 "name": "12V With-Encoder LP"
#                             },
#                             {
#                                 "id": 291,
#                                 "name": "12V With-Encoder MP"
#                             }
#                         ]
#                     },
#                     {
#                         "id": 298,
#                         "name": "Without Encoder",
#                         "children": [
#                             {
#                                 "id": 299,
#                                 "name": "12V HP"
#                             },
#                             {
#                                 "id": 301,
#                                 "name": "12V MP"
#                             },
#                             {
#                                 "id": 303,
#                                 "name": "12V LP"
#                             },
#                             {
#                                 "id": 304,
#                                 "name": "6V HP"
#                             },
#                             {
#                                 "id": 305,
#                                 "name": "6V LP"
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "id": 246,
#                 "name": "Diameter 20mm",
#                 "children": [
#                     {
#                         "id": 318,
#                         "name": "Without Encoder"
#                     },
#                     {
#                         "id": 319,
#                         "name": "With Encoder"
#                     }
#                 ]
#             },
#             {
#                 "id": 310,
#                 "name": "Diameter 12mm",
#                 "children": [
#                     {
#                         "id": 248,
#                         "name": "Single-Shaft",
#                         "children": [
#                             {
#                                 "id": 250,
#                                 "name": "6V Single-Shaft LP"
#                             },
#                             {
#                                 "id": 251,
#                                 "name": "6V Single-Shaft MP"
#                             },
#                             {
#                                 "id": 252,
#                                 "name": "6V Single-Shaft HP"
#                             },
#                             {
#                                 "id": 253,
#                                 "name": "6V Single-Shaft HPCB"
#                             },
#                             {
#                                 "id": 254,
#                                 "name": "12V Single-Shaft HPCB"
#                             }
#                         ]
#                     },
#                     {
#                         "id": 311,
#                         "name": "Dual-Shaft",
#                         "children": [
#                             {
#                                 "id": 312,
#                                 "name": "6V Dual-Shaft LP"
#                             },
#                             {
#                                 "id": 313,
#                                 "name": "6V Dual-Shaft MP"
#                             },
#                             {
#                                 "id": 314,
#                                 "name": "6V Dual-Shaft HP"
#                             },
#                             {
#                                 "id": 315,
#                                 "name": "6V Dual-Shaft HPCB"
#                             },
#                             {
#                                 "id": 316,
#                                 "name": "12V Dual-Shaft HPCB"
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "id": 306,
#         "name": "Dev Platform",
#         "children": [
#             {
#                 "id": 232,
#                 "name": "AI"
#             },
#             {
#                 "id": 234,
#                 "name": "Raspberry Pi"
#             },
#             {
#                 "id": 235,
#                 "name": "Arduino"
#             },
#             {
#                 "id": 307,
#                 "name": "Components",
#                 "children": [
#                     {
#                         "id": 329,
#                         "name": "Cameras",
#                         "children": [
#                             {
#                                 "id": 330,
#                                 "name": "Single Cameras"
#                             },
#                             {
#                                 "id": 331,
#                                 "name": "Binocular Cameras"
#                             }
#                         ]
#                     },
#                     {
#                         "id": 332,
#                         "name": "Expansions"
#                     }
#                 ]
#             },
#             {
#                 "id": 308,
#                 "name": "Accessories",
#                 "children": [
#                     {
#                         "id": 366,
#                         "name": "Wireless NIC"
#                     }
#                 ]
#             },
#             {
#                 "id": 317,
#                 "name": "micro:bit"
#             }
#         ]
#     },
#     {
#         "id": 395,
#         "name": "M5"
#     },
#     {
#         "id": 399,
#         "name": "Raspberry Pi",
#         "children": [
#             {
#                 "id": 400,
#                 "name": "Boards / Kits"
#             },
#             {
#                 "id": 401,
#                 "name": "Displays"
#             },
#             {
#                 "id": 402,
#                 "name": "Cameras"
#             },
#             {
#                 "id": 403,
#                 "name": "HATs"
#             },
#             {
#                 "id": 404,
#                 "name": "All-in-one"
#             },
#             {
#                 "id": 405,
#                 "name": "Robots"
#             },
#             {
#                 "id": 406,
#                 "name": "Portable Gaming"
#             },
#             {
#                 "id": 407,
#                 "name": "Accessories"
#             }
#         ]
#     },
#     {
#         "id": 408,
#         "name": "AI",
#         "children": [
#             {
#                 "id": 409,
#                 "name": "Boards / Kits"
#             },
#             {
#                 "id": 410,
#                 "name": "Displays"
#             },
#             {
#                 "id": 411,
#                 "name": "Cameras"
#             },
#             {
#                 "id": 412,
#                 "name": "Expansions"
#             },
#             {
#                 "id": 413,
#                 "name": "Robots"
#             },
#             {
#                 "id": 414,
#                 "name": "Accessories"
#             }
#         ]
#     },
#     {
#         "id": 415,
#         "name": "RISC-V",
#         "children": [
#             {
#                 "id": 416,
#                 "name": "Boards / Kits"
#             },
#             {
#                 "id": 417,
#                 "name": "Displays"
#             },
#             {
#                 "id": 418,
#                 "name": "Expansions / Accessories"
#             },
#             {
#                 "id": 419,
#                 "name": "Cameras"
#             }
#         ]
#     },
#     {
#         "id": 420,
#         "name": "Displays",
#         "children": [
#             {
#                 "id": 421,
#                 "name": "LCD"
#             },
#             {
#                 "id": 422,
#                 "name": "OLED"
#             },
#             {
#                 "id": 423,
#                 "name": "e-Paper"
#             },
#             {
#                 "id": 424,
#                 "name": "Accessories"
#             }
#         ]
#     },
#     {
#         "id": 425,
#         "name": "IoT / Communication",
#         "children": [
#             {
#                 "id": 426,
#                 "name": "Long Range Wireless"
#             },
#             {
#                 "id": 427,
#                 "name": "Short Range Wireless"
#             },
#             {
#                 "id": 428,
#                 "name": "Wired Comm / Converter"
#             }
#         ]
#     },
#     {
#         "id": 429,
#         "name": "Misc Modules",
#         "children": [
#             {
#                 "id": 430,
#                 "name": "Cameras / Audio / Video"
#             },
#             {
#                 "id": 431,
#                 "name": "Sensors"
#             },
#             {
#                 "id": 432,
#                 "name": "Motors / Servos"
#             },
#             {
#                 "id": 433,
#                 "name": "Others"
#             }
#         ]
#     },
#     {
#         "id": 434,
#         "name": "Robotics"
#     },
#     {
#         "id": 441,
#         "name": "Arduino-Related / Nucleo",
#         "children": [
#             {
#                 "id": 442,
#                 "name": "Boards / Kits"
#             },
#             {
#                 "id": 443,
#                 "name": "Shields"
#             },
#             {
#                 "id": 444,
#                 "name": "Robots"
#             }
#         ]
#     },
#     {
#         "id": 445,
#         "name": "micro:bit",
#         "children": [
#             {
#                 "id": 446,
#                 "name": "Boards / Kits"
#             },
#             {
#                 "id": 447,
#                 "name": "Expansions"
#             },
#             {
#                 "id": 448,
#                 "name": "Robots"
#             }
#         ]
#     },
#     {
#         "id": 449,
#         "name": "MCU / ARM",
#         "children": [
#             {
#                 "id": 450,
#                 "name": "Core Boards / Compact Boards"
#             },
#             {
#                 "id": 451,
#                 "name": "Development Boards / Expansions"
#             },
#             {
#                 "id": 452,
#                 "name": "Debugger / Programmer"
#             },
#             {
#                 "id": 453,
#                 "name": "Programming Adapters"
#             }
#         ]
#     },
#     {
#         "id": 454,
#         "name": "FPGA"
#     },
#     {
#         "id": 455,
#         "name": "Sockets / Adapters"
#     }
# ]

# %%
tree_structure
# Out:
# [{'id': 107, 'name': 'Sensor'},
#  {'id': 237,
#   'name': 'Robotics',
#   'children': [{'id': 249, 'name': 'Accessories'},
#    {'id': 309, 'name': 'Component'},
#    {'id': 435, 'name': 'Mobile Robots'},
#    {'id': 436, 'name': 'Dog-like Robots'},
#    {'id': 437, 'name': 'Drivers / Sensors / Lidar'},
#    {'id': 438, 'name': 'Motors / Servos'},
#    {'id': 439, 'name': 'Robot Arm / Control'},
#    {'id': 440, 'name': 'Robotic Components'}]},
#  {'id': 238,
#   'name': 'Prototyping',
#   'children': [{'id': 255,
#     'name': 'Connector Plug',
#     'children': [{'id': 257,
#       'name': 'JST Connector',
#       'children': [{'id': 261, 'name': 'JST PH'},
#        {'id': 263, 'name': 'JST XH'},
#        {'id': 265, 'name': 'JST PA'},
#        {'id': 267, 'name': 'JST XA'},
#        {'id': 269, 'name': 'JST SM'},
#        {'id': 270, 'name': 'JST EL'},
#        {'id': 271, 'name': 'JST SYP'},
#        {'id': 320, 'name': 'JST ZH'},
#        {'id': 321, 'name': 'JST VH'},
#        {'id': 323, 'name': 'JST CH'},
#        {'id': 338, 'name': 'JST GH'},
#        {'id': 339, 'name': 'JST SH'}]},
#      {'id': 322, 'name': 'DuPont'},
#      {'id': 328, 'name': 'Molex'},
#      {'id': 456, 'name': 'Automotive Connector'}]},
#    {'id': 256,
#     'name': 'Speaker',
#     'children': [{'id': 260,
#       'name': 'Speaker CQR3070',
#       'children': [{'id': 278, 'name': '8Ω5W'},
#        {'id': 279, 'name': '8Ω3W'},
#        {'id': 280, 'name': '4Ω3W'}]}]},
#    {'id': 259,
#     'name': 'Serial Port Converter',
#     'children': [{'id': 274, 'name': 'USB to RS422 or RS485'},
#      {'id': 275, 'name': 'RS232 to RS422/RS485'},
#      {'id': 276, 'name': 'RS232 to RS485'},
#      {'id': 367, 'name': 'USB to RS232'}]},
#    {'id': 295,
#     'name': 'Connect Cable',
#     'children': [{'id': 296, 'name': 'XT60 Cable'}]},
#    {'id': 324,
#     'name': 'Screws and Nuts',
#     'children': [{'id': 325,
#       'name': 'PC Clear Acrylic',
#       'children': [{'id': 326, 'name': 'M3'},
#        {'id': 327, 'name': 'M2.5'},
#        {'id': 340, 'name': 'M4'},
#        {'id': 341, 'name': 'M5'},
#        {'id': 342, 'name': 'M6'}]},
#      {'id': 389,
#       'name': 'Nylon Black',
#       'children': [{'id': 390, 'name': 'M2'},
#        {'id': 391, 'name': 'M2.5'},
#        {'id': 392, 'name': 'M3'},
#        {'id': 393, 'name': 'M4'},
#        {'id': 396, 'name': 'M5'},
#        {'id': 397, 'name': 'M6'},
#        {'id': 398, 'name': 'M8'}]}]},
#    {'id': 333,
#     'name': 'Jumper Cap',
#     'children': [{'id': 334, 'name': '5.08mm'},
#      {'id': 335, 'name': '2.54mm'},
#      {'id': 336, 'name': '2.0mm'}]},
#    {'id': 352,
#     'name': 'PCB Soldering Terminal',
#     'children': [{'id': 353, 'name': 'M3'}, {'id': 354, 'name': 'M4'}]},
#    {'id': 355,
#     'name': 'IDC Box Header Connector',
#     'children': [{'id': 356, 'name': '2.54mm Pitch'},
#      {'id': 394, 'name': '2.0mm Pitch'}]},
#    {'id': 360,
#     'name': 'DIP Switch SMT',
#     'children': [{'id': 343,
#       'name': '1.27 mm Pitch',
#       'children': [{'id': 344, 'name': '1 Position'},
#        {'id': 345, 'name': '2 Position'},
#        {'id': 346, 'name': '3 Position'},
#        {'id': 347, 'name': '4 Position'},
#        {'id': 348, 'name': '5 Position'},
#        {'id': 349, 'name': '6 Position'},
#        {'id': 350, 'name': '8 Position'},
#        {'id': 351, 'name': '10 Position'}]}]},
#    {'id': 457,
#     'name': 'DC Power Plug',
#     'children': [{'id': 458, 'name': 'Female Plug'},
#      {'id': 459, 'name': 'Male Plug'}]}]},
#  {'id': 242,
#   'name': 'DC Gearmotors ',
#   'children': [{'id': 243,
#     'name': 'Diameter 37mm',
#     'children': [{'id': 244,
#       'name': 'With Encoder',
#       'children': [{'id': 293, 'name': '12V With Encoder'},
#        {'id': 294, 'name': '24V With Encoder'}]},
#      {'id': 297,
#       'name': 'Without Encoder',
#       'children': [{'id': 300, 'name': '12V Without Encoder'},
#        {'id': 302, 'name': '24V Without Encoder'}]}]},
#    {'id': 245,
#     'name': 'Diameter 25mm',
#     'children': [{'id': 286,
#       'name': 'With Encoder',
#       'children': [{'id': 287, 'name': '6V With-Encoder HP'},
#        {'id': 288, 'name': '6V With-Encoder LP'},
#        {'id': 289, 'name': '12V With-Encoder HP'},
#        {'id': 290, 'name': '12V With-Encoder LP'},
#        {'id': 291, 'name': '12V With-Encoder MP'}]},
#      {'id': 298,
#       'name': 'Without Encoder',
#       'children': [{'id': 299, 'name': '12V HP'},
#        {'id': 301, 'name': '12V MP'},
#        {'id': 303, 'name': '12V LP'},
#        {'id': 304, 'name': '6V HP'},
#        {'id': 305, 'name': '6V LP'}]}]},
#    {'id': 246,
#     'name': 'Diameter 20mm',
#     'children': [{'id': 318, 'name': 'Without Encoder'},
#      {'id': 319, 'name': 'With Encoder'}]},
#    {'id': 310,
#     'name': 'Diameter 12mm',
#     'children': [{'id': 248,
#       'name': 'Single-Shaft',
#       'children': [{'id': 250, 'name': '6V Single-Shaft LP'},
#        {'id': 251, 'name': '6V Single-Shaft MP'},
#        {'id': 252, 'name': '6V Single-Shaft HP'},
#        {'id': 253, 'name': '6V Single-Shaft HPCB'},
#        {'id': 254, 'name': '12V Single-Shaft HPCB'}]},
#      {'id': 311,
#       'name': 'Dual-Shaft',
#       'children': [{'id': 312, 'name': '6V Dual-Shaft LP'},
#        {'id': 313, 'name': '6V Dual-Shaft MP'},
#        {'id': 314, 'name': '6V Dual-Shaft HP'},
#        {'id': 315, 'name': '6V Dual-Shaft HPCB'},
#        {'id': 316, 'name': '12V Dual-Shaft HPCB'}]}]}]},
#  {'id': 306,
#   'name': 'Dev Platform',
#   'children': [{'id': 232, 'name': 'AI'},
#    {'id': 234, 'name': 'Raspberry Pi'},
#    {'id': 235, 'name': 'Arduino'},
#    {'id': 307,
#     'name': 'Components',
#     'children': [{'id': 329,
#       'name': 'Cameras',
#       'children': [{'id': 330, 'name': 'Single Cameras'},
#        {'id': 331, 'name': 'Binocular Cameras'}]},
#      {'id': 332, 'name': 'Expansions'}]},
#    {'id': 308,
#     'name': 'Accessories',
#     'children': [{'id': 366, 'name': 'Wireless NIC'}]},
#    {'id': 317, 'name': 'micro:bit'}]},
#  {'id': 395, 'name': 'M5'},
#  {'id': 399,
#   'name': 'Raspberry Pi',
#   'children': [{'id': 400, 'name': 'Boards / Kits'},
#    {'id': 401, 'name': 'Displays'},
#    {'id': 402, 'name': 'Cameras'},
#    {'id': 403, 'name': 'HATs'},
#    {'id': 404, 'name': 'All-in-one'},
#    {'id': 405, 'name': 'Robots'},
#    {'id': 406, 'name': 'Portable Gaming'},
#    {'id': 407, 'name': 'Accessories'}]},
#  {'id': 408,
#   'name': 'AI',
#   'children': [{'id': 409, 'name': 'Boards / Kits'},
#    {'id': 410, 'name': 'Displays'},
#    {'id': 411, 'name': 'Cameras'},
#    {'id': 412, 'name': 'Expansions'},
#    {'id': 413, 'name': 'Robots'},
#    {'id': 414, 'name': 'Accessories'}]},
#  {'id': 415,
#   'name': 'RISC-V',
#   'children': [{'id': 416, 'name': 'Boards / Kits'},
#    {'id': 417, 'name': 'Displays'},
#    {'id': 418, 'name': 'Expansions / Accessories'},
#    {'id': 419, 'name': 'Cameras'}]},
#  {'id': 420,
#   'name': 'Displays',
#   'children': [{'id': 421, 'name': 'LCD'},
#    {'id': 422, 'name': 'OLED'},
#    {'id': 423, 'name': 'e-Paper'},
#    {'id': 424, 'name': 'Accessories'}]},
#  {'id': 425,
#   'name': 'IoT / Communication',
#   'children': [{'id': 426, 'name': 'Long Range Wireless'},
#    {'id': 427, 'name': 'Short Range Wireless'},
#    {'id': 428, 'name': 'Wired Comm / Converter'}]},
#  {'id': 429,
#   'name': 'Misc Modules',
#   'children': [{'id': 430, 'name': 'Cameras / Audio / Video'},
#    {'id': 431, 'name': 'Sensors'},
#    {'id': 432, 'name': 'Motors / Servos'},
#    {'id': 433, 'name': 'Others'}]},
#  {'id': 434, 'name': 'Robotics'},
#  {'id': 441,
#   'name': 'Arduino-Related / Nucleo',
#   'children': [{'id': 442, 'name': 'Boards / Kits'},
#    {'id': 443, 'name': 'Shields'},
#    {'id': 444, 'name': 'Robots'}]},
#  {'id': 445,
#   'name': 'micro:bit',
#   'children': [{'id': 446, 'name': 'Boards / Kits'},
#    {'id': 447, 'name': 'Expansions'},
#    {'id': 448, 'name': 'Robots'}]},
#  {'id': 449,
#   'name': 'MCU / ARM',
#   'children': [{'id': 450, 'name': 'Core Boards / Compact Boards'},
#    {'id': 451, 'name': 'Development Boards / Expansions'},
#    {'id': 452, 'name': 'Debugger / Programmer'},
#    {'id': 453, 'name': 'Programming Adapters'}]},
#  {'id': 454, 'name': 'FPGA'},
#  {'id': 455, 'name': 'Sockets / Adapters'}]

# %%
# 保存为JSON文件
with open("tree_structure.json", "w", encoding="utf-8") as f:
    json.dump(tree_structure, f, ensure_ascii=False, indent=4)
